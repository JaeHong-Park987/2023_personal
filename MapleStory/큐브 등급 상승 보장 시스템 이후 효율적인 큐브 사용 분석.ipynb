# %% [markdown]
# # 큐브 등급 상승 보장 시스템 이후 효율적인 큐브 사용 분석
# * 등급 상승 확률
#     * 레드 큐브
#         * 레어 -> 에픽 : 6%
#         * 에픽 -> 유니크 : 1.8%
#         * 유니크 -> 레전드리 : 0.3%
#     * 블랙 큐브
#         * 레어 -> 에픽 : 15%
#         * 에픽 -> 유니크 : 3.5%
#         * 유니크 -> 레전드리 : 1.4%
# * 큐브 등급 상승 보장 시스템
#     * 레드 큐브
#         * 레어 -> 에픽 :  25개
#         * 에픽 -> 유니크 : 83개
#         * 유니크 -> 레전드리 : 500게
#     * 블랙 큐브
#         * 레어 -> 에픽: 10개
#         * 에픽 -> 유니크 : 42개
#         * 유니크 -> 레전드리 : 107개
#
# * 가격
#     * 레드 큐브
#         * 본섭 : 1200원(11개 한 번에 구매 시 25% 할인하여 9900원) / 2206만 3456 ~ 4944만 4444 -> 경매장 시세 기준(매일 다름)
#         * 리부트 : 1,250만 메소
#     * 블랙 큐브
#         * 본섭: 2200원(11개 한 번에 구매 시 25% 할인하여 18150원) / 6627만 2727 ~ 9999만 9999 -> 경매장 시세 기준(매일 다름)
#         * 리부트 : 2,260만 메소

# %% [markdown]
# ## 큐브 등급 상승 보장 시스템 개수와 실제 확률과의 차이

# %% [markdown]
# ## 레어 -> 에픽
# * 에픽으로 등급 상승하기 위해서는 큐브를 사용하는 것 보다는 에픽잠재주문서를 사용하는게 더 좋을 것 같다.

# %% [markdown]
# ## 애팍 -> 유니크

# %% [markdown]
# ## 유니크 -> 레전드리
